# %%
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# Out:
# ...
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# ...
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# ...
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("matches.csv")

# %%
df
# Out:
#       Unnamed: 0        date   time            comp         round  day venue  \
# 0              1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away
# 1              2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home
# 2              3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home
# 3              4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away
# 4              6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home
# ...          ...         ...    ...             ...           ...  ...   ...
# 1384          38  2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away
# 1385          39  2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home
# 1386          40  2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away
# 1387          41  2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away
# 1388          42  2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home
#
# ...

# %%
df = df.drop(columns=["Unnamed: 0", "match report", "notes"], errors="ignore")

# %%
df.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 0  2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away      L  0.0  1.0
# 1  2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home      W  5.0  0.0
# 2  2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home      W  5.0  0.0
# 3  2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away      W  1.0  0.0
# 4  2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home      D  0.0  0.0
#
#          opponent  ...  formation          referee    sh   sot  dist   fk  \
# 0       Tottenham  ...      4-3-3   Anthony Taylor  18.0   4.0  16.9  1.0
# 1    Norwich City  ...      4-3-3     Graham Scott  16.0   4.0  17.3  1.0
# 2         Arsenal  ...      4-3-3  Martin Atkinson  25.0  10.0  14.3  0.0
# 3  Leicester City  ...      4-3-3     Paul Tierney  25.0   8.0  14.0  0.0
# 4     Southampton  ...      4-3-3    Jonathan Moss  16.0   1.0  15.7  1.0
#
#     pk  pkatt  season             team
# ...

# %%
x = df.iloc[:,:-1].values
y = df.iloc[:,-1].values

# %%
df.size
# Out:
# 34725

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1389 entries, 0 to 1388
# Data columns (total 25 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1389 non-null   object
#  1   time        1389 non-null   object
#  2   comp        1389 non-null   object
#  3   round       1389 non-null   object
#  4   day         1389 non-null   object
#  5   venue       1389 non-null   object
#  6   result      1389 non-null   object
#  7   gf          1389 non-null   float64
#  8   ga          1389 non-null   float64
#  9   opponent    1389 non-null   object
#  10  xg          1389 non-null   float64
#  11  xga         1389 non-null   float64
#  12  poss        1389 non-null   float64
#  13  attendance  693 non-null    float64
#  14  captain     1389 non-null   object
#  15  formation   1389 non-null   object
#  16  referee     1389 non-null   object
#  17  sh          1389 non-null   float64
# ...

# %%
df.describe()
# Out:
#                 gf           ga           xg          xga         poss  \
# count  1389.000000  1389.000000  1389.000000  1389.000000  1389.000000
# mean      1.335493     1.380850     1.304176     1.338445    49.702664
# std       1.274235     1.291049     0.767268     0.789360    12.401897
# min       0.000000     0.000000     0.000000     0.000000    18.000000
# 25%       0.000000     0.000000     0.700000     0.700000    40.000000
# 50%       1.000000     1.000000     1.200000     1.200000    50.000000
# 75%       2.000000     2.000000     1.800000     1.800000    59.000000
# max       9.000000     9.000000     4.600000     5.000000    82.000000
#
#          attendance           sh          sot         dist           fk  \
# count    693.000000  1389.000000  1389.000000  1388.000000  1389.000000
# mean   36089.963925    12.153348     4.041037    17.011527     0.455724
# std    17797.991778     5.268876     2.403866     2.988364     0.665389
# ...

# %%
df = df.sort_values(by = 'date').reset_index(drop=True).copy()

# %%
df
# Out:
#             date   time            comp         round  day venue result   gf  \
# 0     2020-09-12  17:30  Premier League   Matchweek 1  Sat  Home      W  4.0
# 1     2020-09-12  20:00  Premier League   Matchweek 1  Sat  Home      L  0.0
# 2     2020-09-12  15:00  Premier League   Matchweek 1  Sat  Home      W  1.0
# 3     2020-09-12  20:00  Premier League   Matchweek 1  Sat  Away      W  2.0
# 4     2020-09-12  12:30  Premier League   Matchweek 1  Sat  Away      W  3.0
# ...          ...    ...             ...           ...  ...   ...    ...  ...
# 1384  2022-04-24  14:00  Premier League  Matchweek 34  Sun  Home      W  1.0
# 1385  2022-04-24  14:00  Premier League  Matchweek 34  Sun  Home      D  2.0
# 1386  2022-04-24  14:00  Premier League  Matchweek 34  Sun  Away      D  2.0
# 1387  2022-04-25  20:00  Premier League  Matchweek 34  Mon  Home      D  0.0
# 1388  2022-04-25  20:00  Premier League  Matchweek 34  Mon  Away      D  0.0
#
# ...

# %% [markdown]
# ### Handling missing data

# %%
import numpy as np
from sklearn.impute import SimpleImputer

numeric_cols = df.select_dtypes(include=[np.number]).columns
numeric_cols = df[numeric_cols].columns[~df[numeric_cols].isna().all()]

imputer = SimpleImputer(strategy='mean')
df[numeric_cols] = imputer.fit_transform(df[numeric_cols])

# %%
# 1. Drop junk columns (if not already done)
df = df.drop(columns=["Unnamed: 0", "match report", "notes"], errors="ignore")

# 2. Define features and target
X_raw = df.drop(columns=["result"])
y = df["result"]

# %%
import numpy as np
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline

# %%
numeric_cols = df.select_dtypes(include=[np.number]).columns
categorical_cols = df.select_dtypes(exclude=[np.number]).columns

# %%
numeric_pipeline = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="mean"))
])

categorical_pipeline = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("onehot", OneHotEncoder(handle_unknown="ignore"))
])

# %%
ct = ColumnTransformer(
    transformers=[
        ("num", numeric_pipeline, numeric_cols),
        ("cat", categorical_pipeline, categorical_cols)
    ]
)

# %%
X = ct.fit_transform(df)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

model = Pipeline(steps=[
    ("preprocess", ct),
    ("classifier", LogisticRegression(max_iter=1000, multi_class="auto"))
])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_raw, y,
    test_size=0.2,
    random_state=42,
    stratify=y
)

# %%
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Documents/projects/Football Data Analysis/venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'result'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
